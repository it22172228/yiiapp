# %% [markdown]
# <a href="https://colab.research.google.com/github/it22172228/yiiapp/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7f81472c-c03f-4ba5-ab7f-4f947b185025" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f81472c-c03f-4ba5-ab7f-4f947b185025">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### 2. Load Dataset
#
# You can download the News Category Dataset from Kaggle: [https://www.kaggle.com/datasets/rmisra/news-category-dataset](https://www.kaggle.com/datasets/rmisra/news-category-dataset).
#
# **Option 1: Manual Upload**
# You can manually upload the `News_Category_Dataset_v3.json` file using the file browser in the left sidebar or by running the following cell:

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-77776209-3157-4ef1-a24d-d22ddf55ca4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-77776209-3157-4ef1-a24d-d22ddf55ca4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Option 2: Kaggle API**
# Alternatively, if you have the Kaggle API installed and configured, you can download the dataset directly. Replace `your_kaggle_username` and `your_kaggle_key` with your actual credentials.

# %%
# # Install Kaggle API
# !pip install kaggle

# # Create .kaggle directory and copy kaggle.json (replace with your key)
# # import json
# # import os
# # user = "your_kaggle_username"
# # key = "your_kaggle_key"
# # tok = {"username":user,"key":key}
# # !mkdir ~/.kaggle
# # with open('/root/.kaggle/kaggle.json', 'w') as f:
# #     json.dump(tok, f)
# # !chmod 600 /root/.kaggle/kaggle.json

# # Download the dataset (uncomment and run if using Kaggle API)
# # !kaggle datasets download -d rmisra/news-category-dataset
# # !unzip news-category-dataset.zip

# %%
import pandas as pd

# Assuming the uploaded file name is 'News_Category_Dataset_v3.json'
# You might need to change this if your uploaded file has a different name.
file_name = next(iter(uploaded))
df = pd.read_json(file_name, lines=True)

# Display the first 5 rows
print("First 5 rows of the dataset:")
display(df.head())

# Display dataset information
print("\nDataset Info:")
display(df.info())

# Keep only relevant columns
df = df[['headline', 'short_description', 'category']]

# Drop rows with null/empty values
df.dropna(inplace=True)

print("\nDataset after dropping null values:")
display(df.info())

# %% [markdown]
# # mBERT – News Category Classification
#
# **Author:** [Your Name Here]
#
# This notebook demonstrates fine-tuning a multilingual BERT (mBERT) model for classifying news headlines and short descriptions into predefined categories using the News Category Dataset from Kaggle.

# %% [markdown]
# **Runtime Setup:**
#
# Please ensure you are using a GPU runtime for faster training. Go to `Runtime > Change runtime type > Hardware accelerator` and select `GPU`.

# %% [markdown]
# ### 1. Setup

# %%
# Install necessary libraries
# !pip install transformers datasets torch scikit-learn pandas matplotlib seaborn tqdm

# Import libraries
import transformers
import torch
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import datasets
from tqdm.auto import tqdm

print("Libraries installed and imported.")
# Out:
# ...
# Libraries installed and imported.

# %% [markdown]
# ### 6. Model Training

# %%
from transformers import BertForSequenceClassification, get_linear_schedule_with_warmup
from torch.optim import AdamW # Corrected import
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
import random
import time
import torch # Import torch

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

# Load pre-trained mBERT model
# We need to specify the number of output labels for our classification task
num_labels = len(label_encoder.classes_) # Get the number of unique categories
model = BertForSequenceClassification.from_pretrained(
    'bert-base-multilingual-cased',
    num_labels=num_labels,
    output_attentions=False,
    output_hidden_states=False,
)

# Move model to the selected device
model.to(device)

# Set up optimizer and learning rate scheduler
optimizer = AdamW(model.parameters(), lr=2e-5, eps=1e-8)

# Number of training epochs
EPOCHS = 3 # You can adjust this

total_steps = len(train_data_loader) * EPOCHS
scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps
)

# Function to calculate accuracy
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return accuracy_score(labels_flat, pred_flat)

# Set the seed for reproducibility
def set_seed(seed_value=42):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)

set_seed(42)

# Training loop
print("\nStarting training loop...")
for epoch in range(EPOCHS):
    print(f"\n======== Epoch {epoch + 1} / {EPOCHS} ========")
    t0 = time.time()
    total_train_loss = 0

    model.train() # Set model to training mode

    for step, batch in enumerate(train_data_loader):
        # Progress update every 40 batches.
        if step % 40 == 0 and not step == 0:
            elapsed = time.time() - t0
            print(f'  Batch {step:>5,}  of  {len(train_data_loader):>5,}. Elapsed: {elapsed:.2f} s.')

        b_input_ids = batch['input_ids'].to(device)
        b_attention_mask = batch['attention_mask'].to(device)
        b_labels = batch['targets'].to(device)

        model.zero_grad() # Clear previously calculated gradients

        outputs = model(b_input_ids,
                        attention_mask=b_attention_mask,
                        labels=b_labels)

        loss = outputs.loss
        total_train_loss += loss.item()

        loss.backward() # Perform a backward pass to calculate gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0) # Clip the norm of the gradients to 1.0 to prevent the "exploding gradients" problem.

        optimizer.step() # Update parameters and take a step using the computed gradient
        scheduler.step() # Update the learning rate

    avg_train_loss = total_train_loss / len(train_data_loader)
    training_time = time.time() - t0

    print(f"\n  Average training loss: {avg_train_loss:.2f}")
    print(f"  Training epoch took: {training_time:.2f} s.")

    # Validation
    print("\nRunning Validation...")
    t0 = time.time()
    model.eval() # Set model to evaluation mode

    total_eval_accuracy = 0
    total_eval_loss = 0
    nb_eval_steps = 0

    for batch in val_data_loader:
        b_input_ids = batch['input_ids'].to(device)
        b_attention_mask = batch['attention_mask'].to(device)
        b_labels = batch['targets'].to(device)

        with torch.no_grad(): # Do not compute gradients
            outputs = model(b_input_ids,
                            attention_mask=b_attention_mask,
                            labels=b_labels)

        loss = outputs.loss
        total_eval_loss += loss.item()

        logits = outputs.logits
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()

        total_eval_accuracy += flat_accuracy(logits, label_ids)

    avg_eval_loss = total_eval_loss / len(val_data_loader)
    avg_eval_accuracy = total_eval_accuracy / len(val_data_loader)
    validation_time = time.time() - t0

    print(f"  Validation Loss: {avg_eval_loss:.2f}")
    print(f"  Validation Accuracy: {avg_eval_accuracy:.2f}")
    print(f"  Validation took: {validation_time:.2f} s.")

print("\nTraining complete!")
# Out:
# Using device: cuda
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Keyword arguments {'pad_to_max_length': True} not recognized.
# Keyword arguments {'pad_to_max_length': True} not recognized.
# Keyword arguments {'pad_to_max_length': True} not recognized.
# Keyword arguments {'pad_to_max_length': True} not recognized.
# Keyword arguments {'pad_to_max_length': True} not recognized.
# Keyword arguments {'pad_to_max_length': True} not recognized.
# Keyword arguments {'pad_to_max_length': True} not recognized.
# Keyword arguments {'pad_to_max_length': True} not recognized.
# Keyword arguments {'pad_to_max_length': True} not recognized.
# ...

# %% [markdown]
# ### 5. Model Preparation

# %%
from transformers import BertTokenizer
import torch
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

# Load the mBERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

# Define a custom dataset
class NewsDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_len):
        self.tokenizer = tokenizer
        self.data = dataframe
        self.text = dataframe['text']
        self.targets = dataframe['category_encoded']
        self.max_len = max_len

    def __len__(self):
        return len(self.text)

    def __getitem__(self, index):
        text = str(self.text[index])
        target = self.targets[index]

        # Tokenize without padding here; padding will be handled in the collate function
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            # Removed padding='max_length'
            return_attention_mask=True,
            return_tensors='pt', # Return as PyTorch tensors
            truncation=True
        )

        # Squeeze the batch dimension added by return_tensors='pt'
        input_ids = encoding['input_ids'].squeeze(0)
        attention_mask = encoding['attention_mask'].squeeze(0)
        target_tensor = torch.tensor(target, dtype=torch.long)


        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask,
            'labels': target_tensor # Changed key from 'targets' to 'labels'
        }

# Custom collate function to handle padding and stacking
def custom_collate_fn(batch):
    input_ids = [item['input_ids'] for item in batch]
    attention_masks = [item['attention_mask'] for item in batch]
    labels = [item['labels'] for item in batch]

    # Pad sequences to the maximum length in the batch
    input_ids_padded = pad_sequence(input_ids, batch_first=True, padding_value=tokenizer.pad_token_id)
    attention_masks_padded = pad_sequence(attention_masks, batch_first=True, padding_value=0)
    labels_stacked = torch.stack(labels)

    return {
        'input_ids': input_ids_padded,
        'attention_mask': attention_masks_padded,
        'labels': labels_stacked
    }


# Set maximum sequence length and batch size
MAX_LEN = 128 # You might need to adjust this based on your data and resources
TRAIN_BATCH_SIZE = 16
VALID_BATCH_SIZE = 16
TEST_BATCH_SIZE = 16

# Create dataset instances
train_dataset = NewsDataset(train_df.reset_index(drop=True), tokenizer, MAX_LEN)
val_dataset = NewsDataset(val_df.reset_index(drop=True), tokenizer, MAX_LEN)
test_dataset = NewsDataset(test_df.reset_index(drop=True), tokenizer, MAX_LEN)

# Create data loaders with custom collate function
train_data_loader = DataLoader(train_dataset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, collate_fn=custom_collate_fn)
val_data_loader = DataLoader(val_dataset, batch_size=VALID_BATCH_SIZE, shuffle=False, collate_fn=custom_collate_fn)
test_data_loader = DataLoader(test_dataset, batch_size=TEST_BATCH_SIZE, shuffle=False, collate_fn=custom_collate_fn)


print("Data loaders created with custom collate function.")
# Out:
# Data loaders created with custom collate function.

# %% [markdown]
# ### 4. Data Splitting

# %%
from sklearn.model_selection import train_test_split

# Split data into training and temporary sets (for validation and testing)
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df['category'])

# Split the temporary set into validation and test sets
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42, stratify=temp_df['category'])

print("Training set shape:", train_df.shape)
print("Validation set shape:", val_df.shape)
print("Test set shape:", test_df.shape)

# Display the distribution of categories in the training set to verify stratification
print("\nCategory distribution in training set:")
display(train_df['category'].value_counts(normalize=True).head())
# Out:
# Training set shape: (167621, 5)
# Validation set shape: (20953, 5)
# Test set shape: (20953, 5)
#
# Category distribution in training set:
# category
# POLITICS          0.169913
# WELLNESS          0.085646
# ENTERTAINMENT     0.082860
# TRAVEL            0.047249
# STYLE & BEAUTY    0.046838
# Name: proportion, dtype: float64

# %% [markdown]
# ### 3. Data Cleaning

# %%
import re
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# Convert text columns to lowercase
df['headline'] = df['headline'].str.lower()
df['short_description'] = df['short_description'].str.lower()

# Function to clean text
def clean_text(text):
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # Remove HTML tags
    text = re.sub(r'<.*?>', '', text)
    # Remove special characters and punctuation
    text = re.sub(r'[^a-z0-9\s]', '', text)
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Apply cleaning to text columns
df['headline'] = df['headline'].apply(clean_text)
df['short_description'] = df['short_description'].apply(clean_text)

# Combine headline and short_description into a new 'text' column
df['text'] = df['headline'] + ' ' + df['short_description']

# Encode category labels
label_encoder = LabelEncoder()
df['category_encoded'] = label_encoder.fit_transform(df['category'])

# Display the top 10 most frequent categories
plt.figure(figsize=(12, 6))
sns.countplot(y='category', data=df, order=df['category'].value_counts().nlargest(10).index)
plt.title('Top 10 Most Frequent News Categories')
plt.xlabel('Number of Articles')
plt.ylabel('Category')
plt.show()

print("\nDataFrame after cleaning and encoding:")
display(df.head())
display(df.info())
# Out:
# DataFrame after cleaning and encoding:
#                                             headline  \
# 0  over 4 million americans roll up sleeves for o...
# 1  american airlines flyer charged banned for lif...
# 2  23 of the funniest tweets about cats and dogs ...
# 3  the funniest tweets from parents this week sep...
# 4  woman who called cops on black birdwatcher los...
#
#                                    short_description   category  \
# 0  health experts said it is too early to predict...  U.S. NEWS
# 1  he was subdued by passengers and crew when he ...  U.S. NEWS
# 2  until you have a dog you dont understand what ...     COMEDY
# 3  accidentally put grownup toothpaste on my todd...  PARENTING
# 4  amy cooper accused investment firm franklin te...  U.S. NEWS
#
#                                                 text  category_encoded
# 0  over 4 million americans roll up sleeves for o...                35
# 1  american airlines flyer charged banned for lif...                35
# ...

# %%
import pandas as pd

# Assuming the uploaded file name is 'News_Category_Dataset_v3.json'
# You might need to change this if your uploaded file has a different name.
file_name = next(iter(uploaded))
df = pd.read_json(file_name, lines=True)

# Display the first 5 rows
print("First 5 rows of the dataset:")
display(df.head())

# Display dataset information
print("\nDataset Info:")
display(df.info())

# Keep only relevant columns
df = df[['headline', 'short_description', 'category']]

# Drop rows with null/empty values
df.dropna(inplace=True)

print("\nDataset after dropping null values:")
display(df.info())
# Out:
# First 5 rows of the dataset:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# ...
