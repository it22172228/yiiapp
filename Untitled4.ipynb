# %% [markdown]
# <a href="https://colab.research.google.com/github/it22172228/yiiapp/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets scikit-learn pandas numpy torch sentencepiece
